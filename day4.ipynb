# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishKumar771/colab-python/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [10, 20, 30]

print(len(l))
# Out:
# 3

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(len(l)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(len(l)):
    print(l[i])
# Out:
# 10
# 20
# 30

# %%
def name(a):
  print(a)
name("mani")
# Out:
# mani

# %%
def fname(a,b):
  print(a,b)
name("manish Kumar")
# Out:
# manish Kumar
