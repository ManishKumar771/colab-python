# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishKumar771/colab-python/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("day 2")
# Out:
# day 2
